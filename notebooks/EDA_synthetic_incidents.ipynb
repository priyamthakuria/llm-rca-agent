# %% [markdown]
# # EDA: Synthetic Database Incidents
#
# This notebook explores the synthetic incident dataset.

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from src.data.loader import load_incidents_from_dir

# %%
# Load incidents
incidents = load_incidents_from_dir("data/synthetic")
print(f"Loaded {len(incidents)} incidents")
